# %% [markdown]
# **Wiki Art Web Crawler**

# %%
import requests
import os
import re

class WikiArt :
  def __init__(self) :
    self.baseUrl = "https://www.wikiart.org/en/"
    self.iconArg = "!PinterestSmall"
    self.saveDir = "AbstractPaintings/"

  def downloadPainting(self, painting, isSmall = True) :
    ext = os.path.splitext(painting["image"])[1]
    url = f"{painting['image']}{(self.iconArg if isSmall else '')}{ext}"
    dirPath = f"{self.saveDir}{painting['artistName']}"
    filePath = "{}/{}{}".format(dirPath, re.sub(r'/', '|', painting['title']), ext)

    if not os.path.exists(self.saveDir) :
      os.mkdir(self.saveDir)

    if not os.path.exists(dirPath) :
      os.mkdir(dirPath)

    with open(filePath, "wb") as image :
      image.write(requests.get(url).content)

    with open("lookUp.txt", "a") as lookUp :
      lookUp.write(filePath + "\n")

  def allGenres(self) :
    genres = []
    mode = "artists-by-genre?json=2"

    url = f"{self.baseUrl}{mode}"
    data = requests.get(url).json()

    for genre in data["Dictionaries"] :
      genres.append(genre["Seo"])
    
    return genres

  def findAllPaintingsByArtist(self, artist) :
    dArgs = "json=2&layout=new&page={}&resultType=masonry"
    mode = f"{artist}/mode/all-paintings-by-alphabet?{dArgs}"

    url = f"{self.baseUrl}{mode.format(0)}"

    basePage = requests.get(url).json()
    pages = int(basePage["AllPaintingsCount"] / basePage["PageSize"]) + 1
    basePage["PageSize"] = basePage["AllPaintingsCount"]

    for page in range(1, pages + 1) :
      url = f"{self.baseUrl}{mode.format(page)}"
      r = requests.get(url)

      data = r.json()

      for item in data["Paintings"]:
        basePage["Paintings"].append(item)

    return basePage["Paintings"]

  def findAllArtistsByGenre(self, genre) :
    dArgs = "json=3&searchterm=abstract&layout=new&page={}&resultType=masonry"
    mode = f"App/Search/Artists-by-Genre?{dArgs}"

    url = f"{self.baseUrl}{mode.format(0)}"

    basePage = requests.get(url).json()
    pages = int(basePage["AllArtistsCount"] / basePage["PageSize"]) + 1
    basePage["PageSize"] = basePage["AllArtistsCount"]

    for page in range(0, pages) :
      url = f"{self.baseUrl}{mode.format(page + 1)}"
      r = requests.get(url)

      data = r.json()

      for item in data["Artists"]:
        basePage["Artists"].append(item)

    return basePage["Artists"]

  def findArtists(self, timeRange = False, movement = False, nation = False, field = False, school = False) :
    dVals = []
    dArgs = "?isAjax=true&layout=new&dictIdsJson=[{}]&layout=new&maxYear={}&minYear=-{}&page={}&resultType=masonry"
    mode = f"app/Search/ArtistAdvancedSearch/{dArgs}"

    if timeRange : mode = mode.format("{}", timeRange[1], timeRange[0], "{}")
    else : mode =  mode.format("{}", 2021, -50000, "{}")

    if not (movement or nation or field or school) :
      mode = mode.format("", "{}")

    #movement
    print("movement is not built")
    #naition
    print("naition is not built")
    #field
    print("field is not built")
    #school
    print("school is not built")

    url = f"{self.baseUrl}{mode.format(0)}"
    basePage = requests.get(url).json()

    pages = int(basePage["AllArtistsCount"] / basePage["PageSize"]) + 1
    basePage["PageSize"] = basePage["AllArtistsCount"]

    for page in range(0, pages) :
      url = f"{self.baseUrl}{mode.format(page + 1)}"
      data = requests.get(url).json()

      for item in data["Artists"]:
        basePage["Artists"].append(item)

    return basePage["Artists"]

# %% [markdown]
# **Implementation**

# %%
print(WikiArt().allGenres())
# Out:
# ['abstract', 'advertisement', 'allegorical-painting', 'animal-painting', 'architecture', 'artists-book', 'battle-painting', 'bijinga', 'bird-and-flower-painting', 'calligraphy', 'capriccio', 'caricature', 'cityscape', 'cloudscape', 'design', 'digital', 'figurative', 'flower-painting', 'genre-painting', 'graffiti', 'history-painting', 'icon', 'illustration', 'installation', 'interior', 'jewelry', 'landscape', 'literary-painting', 'manga', 'marina', 'miniature', 'mosaic', 'mural', 'mythological-painting', 'nude-painting-nu', 'pastorale', 'performance', 'photo', 'pin-up', 'portrait', 'poster', 'quadratura', 'religious-painting', 'sculpture', 'self-portrait', 'shan-shui', 'sketch-and-study', 'still-life', 'symbolic-painting', 'tapestry', 'tessellation', 'trompe-loeil', 'tronie', 'urushi-e', 'utensil', 'vanitas', 'veduta', 'video-art', 'wildlife-painting', 'yakusha-e']

# %%
import shutil

wiki = WikiArt()

#artists = ["nicholas-roerich", "pablo-picasso", "salvador-dali", "andrei-rublev", "rene-magritte"]
artists = [a["artistUrl"][4:] for a in wiki.findAllArtistsByGenre("abstract")]
print("Artists: \n", artists)

with open("lookUp.txt", "w") as lookUp :
  lookUp.write("")

#dowload all the square dali paintings
print("Dowloading...")
for artist in artists :
  print(artist)
  try :
    paintings = wiki.findAllPaintingsByArtist(artist)

    for paint in paintings : #get only the square(ish) paintings
      w, h = paint["width"], paint["height"]
      if (min(w, h) / max(w, h)) > 0.8 :
        wiki.downloadPainting(paint)
  except : print("--->Did not load")

#archive the paintings for client to dowload
print("Zipping...")
os.rename("lookUp.txt", f"{wiki.saveDir}/lookUp.txt")
shutil.make_archive(wiki.saveDir, "zip", wiki.saveDir)

print("done")
# Out:
# Artists:
#  ['camille-bryen', 'ulfert-wilke', 'ilya-bolotowsky', 'giuseppe-santomaso', 'bruno-munari', 'myron-stout', 'rupprecht-geiger', 'luigi-veronesi', 'maria-helena-vieira-da-silva', 'william-saroyan', 'jorge-oteiza', 'lee-krasner', 'max-bill', 'gustave-singier', 'jack-bush', 'jean-bertholle', 'norman-lewis', 'antonio-corpora', 'jean-le-moal', 'paul-feeley', 'franz-kline', 'hedda-sterne', 'raoul-ubac', 'else-alfelt', 'richard-mortensen', 'aurelie-nemours', 'leon-berkowitz', 'hiroyuki-tajima', 'raul-lozza', 'alfred-manessier', 'olle-baertling', 'lothar-charoux', 'jackson-pollock', 'giulio-turcato', 'afro', 'agnes-martin', 'verena-loewensberg', 'emil-schumacher', 'vasile-dobrian', 'alexander-liberman', 'john-cage', 'morris-louis', 'mario-ballocco', 'jean-michel-atlan', 'william-scott', 'carmelo-arden-quin', 'toko-shinoda', 'conrad-marca-relli', 'philip-guston', 'ad-reinhardt', 'jose-guerrero', 'karl-otto-gotz', 'aurel-cojan', 'peter-busa', 'johannes-jan-schoonhoven', 'nassos-daphnis', 'alexandre-istrati', 'natalia-dumitresco', 'tihamer-gyarmathy', 'robert-motherwell', 'mathias-goeritz', 'friedel-dzubas', 'carmen-herrera', 'bernard-schultze', 'gunther-gerzso', 'terry-frost', 'richard-pousette-dart', 'fernand-leduc', 'pablo-palazuelo', 'lennart-rodhe', 'gottfried-honegger', 'marcelle-loubchansky', 'mario-nigro', 'edna-andrade', 'nicolas-carone', 'jean-degottex', 'rune-jansson', 'paul-reed', 'frederick-hammersley', 'rene-duvillier', 'mira-schendel', 'edward-corbett', 'taro-yamamoto', 'pierre-soulages', 'huguette-arthur-bertrand', 'zao-wou-ki', 'george-saru', 'amilcar-de-castro', 'jimmy-ernst', 'jean-messagier', 'gene-davis', 'chu-teh-chun', 'nadir-afonso', 'frank-lobdell', 'lidy-prati', 'georges-mathieu', 'anne-truitt', 'norman-bluhm', 'bram-bogart', 'ray-parker', 'tomas-maldonado', 'william-turnbull', 's-h-raza', 'emilio-scanavino', 'pedro-coronel', 'jules-olitski', 'jaroslav-serpan', 'ramirez-villamizar', 'sadamasa-motonaga', 'simon-hantai', 'jacques-busse', 'theodoros-stamos', 'ivan-serpa', 'gunter-fruhtrunk', 'jerzy-nowosielski', 'genevieve-asse', 'ellsworth-kelly', 'sam-francis', 'paul-jenkins', 'luigi-guardigli', 'mario-cesariny', 'fernando-lanhas', 'jean-paul-riopelle', 'antonio-sanfilippo', 'antoni-tapies', 'olga-albizu', 'kazuo-shiraga', 'luis-sacilotto', 'akira-kanayama', 'paul-brach', 'herbert-zangs', 'behjat-sadr', 'manabu-mabe', 'martin-barre', 'francois-arnal', 'oskar-holweck', 'richards-ruben', 'joan-mitchell', 'marcel-barbeau', 'etel-adnan', 'edward-krasinski', 'almir-mavignier', 'modest-cuixart', 'john-altoon', 'karl-benjamin', 'stanley-boxer', 'jean-miotte', 'francois-morellet', 'ed-clark', 'hannelore-baron', 'moshe-kupferman', 'stefan-sevastre', 'adnan-coker', 'tony-delap', 'warren-rohrer', 'james-bishop', 'manuel-rivera', 'ludwig-wilding', 'piero-dorazio', 'pierre-alechinsky', 'thomas-downing', 'al-held', 'yun-hyong-keun', 'omar-rayo', 'jean-paul-jerome', 'theo-gerber', 'cy-twombly', 'jagdish-swaminathan', 'jcj-vanderheyden', 'ward-jackson', 'helen-frankenthaler', 'manuel-felguerez', 'li-yuan-chia', 'horacio-garcia-rossi', 'jay-defeo', 'marcia-hafif', 'peter-joseph', 'se-ok-suh', 'constantin-blendea', 'claude-georges', 'nicholas-krushenick', 'turi-simeti', 'ion-alin-gheorghiu', 'luis-feito', 'rodolfo-arico', 'ron-gorchov', 'yuriy-zlotnikov', 'richard-anuszkiewicz', 'robert-ryman', 'gotthard-graubner', 'frederic-matys-thursz', 'enrico-castellani', 'raoul-de-keyser', 'dadamaino', 'charlotte-posenenske', 'howard-mehring', 'park-seo-bo', 'cesar-paternosto', 'joan-hernandez-pijuan', 'richard-smith', 'norman-zammitt', 'heinz-mack', 'bridget-riley', 'antonio-asis', 'rubem-ludolf', 'dorothea-rockburne', 'gebre-kristos-desta', 'gerhard-richter', 'helmut-sturm', 'ion-nicodim', 'jef-verheyen', 'romul-nutiu', 'howard-hodgkin', 'marc-vaux', 'claude-tousignant', 'walter-leblanc', 'bernard-cohen', 'kazuaki-tanahashi', 'fernando-garcia-ponce', 'kuno-gonschior', 'guido-molinari', 'sam-gilliam', 'victor-bonato', 'charles-bezie', 'berna ...
# Dowloading...
# camille-bryen
# ulfert-wilke
# ilya-bolotowsky
#    Did not load
# giuseppe-santomaso
# bruno-munari
# myron-stout
# rupprecht-geiger
# luigi-veronesi
# maria-helena-vieira-da-silva
# william-saroyan
# jorge-oteiza
#    Did not load
# lee-krasner
# max-bill
# gustave-singier
# jack-bush
# jean-bertholle
# norman-lewis
# antonio-corpora
# jean-le-moal
# paul-feeley
# franz-kline
# hedda-sterne
# raoul-ubac
# else-alfelt
# richard-mortensen
# aurelie-nemours
# leon-berkowitz
# hiroyuki-tajima
# raul-lozza
# alfred-manessier
# olle-baertling
# lothar-charoux
# jackson-pollock
# giulio-turcato
# afro
# agnes-martin
# verena-loewensberg
# emil-schumacher
# vasile-dobrian
# alexander-liberman
# john-cage
# morris-louis
# mario-ballocco
# jean-michel-atlan
# william-scott
# carmelo-arden-quin
# toko-shinoda
# conrad-marca-relli
# philip-guston
# ad-reinhardt
# jose-guerrero
# karl-otto-gotz
# aurel-cojan
# peter-busa
# johannes-jan-schoonhoven
# nassos-daphnis
# alexandre-istrati
# natalia-dumitresco
# tihamer-gyarmathy
# robert-motherwell
# mathias-goeritz
# friedel-dzubas
# carmen-herrera
# bernard-schultze
# gunther-gerzso
# terry-frost
# richard-pousette-dart
# fernand-leduc
# pablo-palazuelo
# lennart-rodhe
# gottfried-honegger
# marcelle-loubchansky
# mario-nigro
# edna-andrade
# nicolas-carone
# jean-degottex
# rune-jansson
# paul-reed
# frederick-hammersley
# rene-duvillier
# mira-schendel
# edward-corbett
# taro-yamamoto
# pierre-soulages
# huguette-arthur-bertrand
# zao-wou-ki
# george-saru
# amilcar-de-castro
# jimmy-ernst
# jean-messagier
# gene-davis
# chu-teh-chun
# nadir-afonso
#    Did not load
# frank-lobdell
# lidy-prati
# georges-mathieu
# anne-truitt
# norman-bluhm
# bram-bogart
# ray-parker
# tomas-maldonado
# william-turnbull
# s-h-raza
# emilio-scanavino
# pedro-coronel
# jules-olitski
#    Did not load
# jaroslav-serpan
# ramirez-villamizar
# sadamasa-motonaga
# simon-hantai
# jacques-busse
# theodoros-stamos
# ivan-serpa
# gunter-fruhtrunk
# jerzy-nowosielski
# genevieve-asse
# ellsworth-kelly
# sam-francis
# paul-jenkins
# luigi-guardigli
# mario-cesariny
# fernando-lanhas
# jean-paul-riopelle
# antonio-sanfilippo
# antoni-tapies
# olga-albizu
# kazuo-shiraga
# luis-sacilotto
# akira-kanayama
# paul-brach
# herbert-zangs
# behjat-sadr
# manabu-mabe
# martin-barre
# francois-arnal
# oskar-holweck
# richards-ruben
# joan-mitchell
# marcel-barbeau
# etel-adnan
# edward-krasinski
# almir-mavignier
# modest-cuixart
# john-altoon
# karl-benjamin
# stanley-boxer
# jean-miotte
# francois-morellet
# ed-clark
# hannelore-baron
# moshe-kupferman
# stefan-sevastre
# adnan-coker
# tony-delap
# warren-rohrer
# james-bishop
# manuel-rivera
# ludwig-wilding
# piero-dorazio
# pierre-alechinsky
# thomas-downing
# al-held
# yun-hyong-keun
# omar-rayo
# jean-paul-jerome
# theo-gerber
# cy-twombly
# jagdish-swaminathan
# jcj-vanderheyden
# ward-jackson
# helen-frankenthaler
# manuel-felguerez
# li-yuan-chia
# horacio-garcia-rossi
# jay-defeo
# marcia-hafif
# peter-joseph
# se-ok-suh
# constantin-blendea
# claude-georges
# nicholas-krushenick
# turi-simeti
# ion-alin-gheorghiu
# luis-feito
# rodolfo-arico
# ron-gorchov
# yuriy-zlotnikov
# richard-anuszkiewicz
#    Did not load
# robert-ryman
# gotthard-graubner
# frederic-matys-thursz
# enrico-castellani
# raoul-de-keyser
# dadamaino
# charlotte-posenenske
# howard-mehring
# park-seo-bo
# cesar-paternosto
# joan-hernandez-pijuan
# richard-smith
# norman-zammitt
# heinz-mack
# bridget-riley
# antonio-asis
# rubem-ludolf
# dorothea-rockburne
# gebre-kristos-desta
# gerhard-richter
# helmut-sturm
# ion-nicodim
# jef-verheyen
# romul-nutiu
# howard-hodgkin
# marc-vaux
# claude-tousignant
# walter-leblanc
# bernard-cohen
# kazuaki-tanahashi
# fernando-garcia-ponce
# kuno-gonschior
# guido-molinari
# sam-gilliam
# victor-bonato
# charles-bezie
# bernard-aubertin
# irma-blank
# yves-gaucher
# bob-law
# jeremy-moon
# gerhard-von-graevenitz
# walter-darby-bannard
# john-hoyland
# tadasky
# robert-huot
# roman-cotosman
# guy-mees
# ha-chong-hyun
# agostino-bonalumi
# jerry-w-mcdaniel
# claude-viallat
# constantin-flondor
# lee-ufan
# leo-valledor
# giorgio-griffa
# joachim-bandau
# frank-stella
# edward-avedisian
# rochelle-blumenfeld
# doug-ohlson
# samia-halaby
# monique-orsini
# ronald-davis
# joe-goode
# matsutani
# nasreen-mohamedi
# niele-toroni
# larry-zox
# grazia-varisco
# robert-mangold
# tess-jaray
# pino-pinelli
# michel-parmentier
# pat-steir
# angelo-de-sousa
# daniel-buren
# mark-lancaster
# eduardo-nery
# brice-marden
# jan-groth
# akkitham-narayanan
# andre-pierre-arnal
# rafa-nasiri
# imi-knoebel
# paolo-scheggi
# ettore-spalletti
# phil-sims
# robert-swain
# pat-lipsky
# claude-rutault
# richard-tuttle
# silviu-oravitzan
# daan-lemaire
# gunter-umberg
# blinky-palermo
# joseph-marioni
# florin-maxa
# howardena-pindell
# francois-rouan
# olivier-mosset
# soledad-sevilla
# helmut-federle
# louis-cane
# mary-corse
# ion-pantilie
# sean-scully
# antonio-palolo
# stanley-whitney
# jean-francois-dubreuil
# gary-wragg
# melissa-meyer
# harriet-korman
# ronnie-landfield
# tiberiy-szilvashi
# stephen-mueller
# requena-nozal
# alan-charlton
# gregg-renfrow
# rudolf-de-crignis
# luciano-bartolini
# roger-weik
# troubat-georges
# gerwald-rockenschaub
# peter-halley
# andrzej-nowacki
# gunther-forg
# anne-appleby
# jill-baroff
# bruno-jakob
# michael-krebber
# qin-yufen
# philip-taaffe
# gaylen-gerber
# pedro-cabrita-reis
# jack-armstrong
# charles-gibbons
# barbara-mcgivern
#    Did not load
# heimo-zobernig
# moon-pil-shim
# christian-eckart
# sharon-butler
# iseult-labote
# mostafa-dashti
# eric-zammitt
# sofia-areal
# gennady-mironov
# ding-yi
# callum-innes
# gianni-sarcone
# josignacio
# jan-maarten-voskuil
# carsten-nicolai
# darren-waterston
# mariojose-angeles
# ian-davenport
# daniel-sambo-richter
# bernd-luz
# sarah-morris
# ilse-dhollander
# pablo-rey
# wolfgang-tillmans
# paula-klien
# julie-mehretu
# lorenzo-belenguer
# xu-hongming
# albrecht-behmel
# thomas-riesner
# cameron-platter
# justin-earl-grant
# rodrigo-franzao
# jacob-kassay
# yui-yaegashi
# nemanja-vuckovic
# thiago-boecan
# Zipping...
# done
